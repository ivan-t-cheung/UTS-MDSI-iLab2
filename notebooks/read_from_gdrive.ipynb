# %% [markdown]
# ## This notebook sets out how to read files from google drive ##

# %%
## Install required libraries
# !pip install pydrive

# %%
# Import libraries
# - to read google drive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# - to extract gz files
import gzip
import json

# - to convert json to dataframe
import pandas as pd

# %% [markdown]
# ### Authenticate session using Google Drive API credentials

# %%
## Follow steps outlined in https://pythonhosted.org/PyDrive/quickstart.html#authentication to set up client_secrets.json
## save the client_secrets.json file to the notebook file

## Run to authenticate.

gauth = GoogleAuth()
gauth.LocalWebserverAuth() # Creates local webserver and auto handles authentication.
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=1010998970874-55ji152nek39gamaen2di7dfhf1s16ms.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %% [markdown]
# #### Example 1: How to retreive a list of files from a named folder

# %%
## code to extract a list of ids for all files in a folder.
## the folder is identified by it's ID: in this case, the folder data/raw/patents = '1JTzjr6SByYjwOZocX6pkVuUC3vYfkk7Q'

drive = GoogleDrive(gauth) # Create GoogleDrive instance with authenticated GoogleAuth instance

file_list = drive.ListFile({'q': "'1JTzjr6SByYjwOZocX6pkVuUC3vYfkk7Q' in parents"}).GetList()
for file in file_list:
  print('title: %s, id: %s' % (file['title'], file['id']))
# Out:
# title: 2020-us-patent.jsonl.gz, id: 1Wlesl9kiYSHE80T6TZnY6s3G9MXsib_w
# title: 2021-au-patent.jsonl.gz, id: 1mwnh0PvPnovwPl96ULZDulkMQ9RR69__
# title: 2023-au-patent.jsonl.gz, id: 1H79jIWowBbYViFhrzgZbBJ9WPD4-o3Dj
# title: 2022-us-patent.jsonl.gz, id: 1ss2nzylIczSfF8EUTP5_2HmXwWeZ1hRt
# title: 2023-us-patent.jsonl.gz, id: 1awgN_UNVPPJ6DIikuQLW4A8WBKtD5_WA
# title: 2021-us-patent.jsonl.gz, id: 18JTQ9wOfytCf-f7ByvSrmF83d-b-MufJ

# %% [markdown]
# #### Example 2: How to download a file from google drive

# %%
# retrieve the ID for the first file from the file_list
filename = file_list[0]['title']
file_id = file_list[0]['id']

# %%
# Initialize GoogleDriveFile instance with file id.
file = drive.CreateFile({'id': file_id})

# get the content of the file - this will download the file to your local computer.
content = file.GetContentFile('../data/raw/' + filename)

# %% [markdown]
# #### Example 3: How to extract gzip file using gzip python package

# %%
## Open the gzip file and read the contents, apply decode to convert from bytes to string.
with gzip.open('../data/raw/' + filename, 'rb') as f:
    file_content = f.read().decode('utf8')

# %% [markdown]
# #### Example 4: Working with JSON Lines

# %%
## JSON Lines differs from JSON array by having each JSON object in a new line.
## A reader is needed to iterate through each line. However the first line can simply be extracted by using this partition method.

first_record = file_content.partition('\n')[0]

# %%
# This loads the string 'first_record' into the json package.
patent_json = json.loads(first_record)

# %%
## Print sample json recrod
print(patent_json['jurisdiction'])
print(patent_json['abstract'])
print(patent_json['biblio']['parties']['applicants'][0]['residence'])   ## the residence status of the first applicant party
# Out:
# US
# [{'text': 'A method for improving the ion beam quality in an ion implanter is disclosed. In some ion implantation systems, contaminants from the ion source are extracted with the desired ions, introducing contaminants to the workpiece. These contaminants may be impurities in the ion source chamber. This problem is exacerbated when mass analysis of the extracted ion beam is not performed, and is further exaggerated when the desired feedgas includes a halogen. The introduction of a diluent gas in the ion chamber may reduce the deleterious effects of the halogen on the inner surfaces of the chamber, reducing contaminants in the extracted ion beam. In some embodiments, the diluent gas may be germane or silane.', 'lang': 'en'}]
# US

# %%
patent_json
# Out:
# {'lens_id': '002-152-403-917-266',
#  'jurisdiction': 'US',
#  'doc_number': '10804075',
#  'kind': 'B2',
#  'date_published': '2020-10-13',
#  'doc_key': 'US_10804075_B2_20201013',
#  'docdb_id': 539082606,
#  'lang': 'en',
#  'biblio': {'publication_reference': {'jurisdiction': 'US',
#    'doc_number': '10804075',
#    'kind': 'B2',
#    'date': '2020-10-13'},
#   'application_reference': {'jurisdiction': 'US',
#    'doc_number': '201615350685',
#    'kind': 'A',
#    'date': '2016-11-14'},
#   'priority_claims': {'claims': [{'jurisdiction': 'US',
#      'doc_number': '201615350685',
#      'kind': 'A',
#      'date': '2016-11-14',
#      'sequence': 1},
#     {'jurisdiction': 'US',
#      'doc_number': '201314089916',
#      'kind': 'A',
#      'date': '2013-11-26',
#      'sequence': 2},
#     {'jurisdiction': 'US',
#      'doc_number': '201361847776',
#      'kind': 'P',
#      'date': '2013-07-18',
#      'sequence': 3}],
#    'earliest_claim': {'date': '2013-07-18'}},
#   'invention_title': [{'text': 'Method of improving ion beam quality in an implant system',
#     'lang': 'en'}],
#   'parties': {'examiners': {'primary_examiner': {'department': '1717',
#      'extracted_name': {'value': 'Hai Y Zhang'}}},
#    'applicants': [{'residence': 'US',
#      'extracted_name': {'value': 'VARIAN SEMICONDUCTOR EQUIPMENT ASS INC'}}],
#    'inventors': [{'residence': 'US',
#      'sequence': 1,
#      'extracted_name': {'value': 'GRAFF JOHN W'}},
#     {'residence': 'US',
#      'sequence': 2,
#      'extracted_name': {'value': 'KOO BON-WOONG'}},
#     {'residence': 'US',
#      'sequence': 3,
#      'extracted_name': {'value': 'FRONTIERO JOHN A'}},
#     {'residence': 'US',
#      'sequence': 4,
#      'extracted_name': {'value': 'BATEMAN NICHOLAS P T'}},
#     {'residence': 'US',
#      'sequence': 5,
#      'extracted_name': {'value': 'MILLER TIMOTHY J'}},
#     {'residence': 'US',
#      'sequence': 6,
#      'extracted_name': {'value': 'BHOSLE VIKRAM M'}}],
#    'agents': [{'extracted_name': {'value': 'Nields, Lemack & Frame, LLC'}}]},
#   'classifications_ipcr': {'classifications': [{'symbol': 'C23C14/48'},
#     {'symbol': 'H01J37/08'},
#     {'symbol': 'H01J37/317'},
#     {'symbol': 'H01L21/265'}]},
#   'classifications_cpc': {'classifications': [{'symbol': 'C23C14/48'},
#     {'symbol': 'H01J37/3171'},
#     {'symbol': 'H01J37/3171'},
#     {'symbol': 'H01J37/08'},
#     {'symbol': 'H01J37/08'},
#     {'symbol': 'H01J2237/006'},
#     {'symbol': 'H01J2237/006'},
#     {'symbol': 'H01L21/265'}]},
#   'references_cited': {'citations': [{'sequence': 1,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '9034743',
#        'kind': 'B2',
#        'date': '2015-05-19'},
#       'lens_id': '160-707-291-679-632'},
#      'cited_phase': 'SEA'},
#     {'sequence': 2,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '9524849',
#        'kind': 'B2',
#        'date': '2016-12-20'},
#       'lens_id': '040-039-168-768-531'},
#      'cited_phase': 'SEA'},
#     {'sequence': 3,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2005260354',
#        'kind': 'A1',
#        'date': '2005-11-24'},
#       'lens_id': '003-790-078-785-986'},
#      'cited_phase': 'SEA'},
#     {'sequence': 4,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2008237496',
#        'kind': 'A1',
#        'date': '2008-10-02'},
#       'lens_id': '076-581-600-171-643'},
#      'cited_phase': 'SEA'},
#     {'sequence': 5,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2009090915',
#        'kind': 'A1',
#        'date': '2009-04-09'},
#       'lens_id': '098-798-007-416-721'},
#      'cited_phase': 'SEA'},
#     {'sequence': 6,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2014062286',
#        'kind': 'A1',
#        'date': '2014-03-06'},
#       'lens_id': '089-432-573-809-877'},
#      'cited_phase': 'SEA'},
#     {'sequence': 1,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '4533831',
#        'kind': 'A',
#        'date': '1985-08-06'},
#       'lens_id': '071-442-007-310-890'},
#      'cited_phase': 'APP'},
#     {'sequence': 2,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '7655931',
#        'kind': 'B2',
#        'date': '2010-02-02'},
#       'lens_id': '114-976-336-787-862'},
#      'cited_phase': 'APP'},
#     {'sequence': 3,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '8288741',
#        'kind': 'B1',
#        'date': '2012-10-16'},
#       'lens_id': '131-079-662-469-241'},
#      'cited_phase': 'APP'},
#     {'sequence': 4,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2005098742',
#        'kind': 'A1',
#        'date': '2005-05-12'},
#       'lens_id': '111-509-512-639-657'},
#      'cited_phase': 'APP'},
#     {'sequence': 5,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2007281399',
#        'kind': 'A1',
#        'date': '2007-12-06'},
#       'lens_id': '055-278-461-943-442'},
#      'cited_phase': 'APP'},
#     {'sequence': 6,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2008138967',
#        'kind': 'A1',
#        'date': '2008-06-12'},
#       'lens_id': '060-130-852-686-308'},
#      'cited_phase': 'APP'},
#     {'sequence': 7,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2008179545',
#        'kind': 'A1',
#        'date': '2008-07-31'},
#       'lens_id': '146-822-646-155-077'},
#      'cited_phase': 'APP'},
#     {'sequence': 8,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2008248636',
#        'kind': 'A1',
#        'date': '2008-10-09'},
#       'lens_id': '081-210-931-651-48X'},
#      'cited_phase': 'APP'},
#     {'sequence': 9,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2009200460',
#        'kind': 'A1',
#        'date': '2009-08-13'},
#       'lens_id': '050-990-096-296-757'},
#      'cited_phase': 'APP'},
#     {'sequence': 10,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2009215251',
#        'kind': 'A1',
#        'date': '2009-08-27'},
#       'lens_id': '178-769-727-483-524'},
#      'cited_phase': 'APP'},
#     {'sequence': 11,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2010140077',
#        'kind': 'A1',
#        'date': '2010-06-10'},
#       'lens_id': '065-350-712-251-587'},
#      'cited_phase': 'APP'},
#     {'sequence': 12,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2011143527',
#        'kind': 'A1',
#        'date': '2011-06-16'},
#       'lens_id': '083-019-233-660-001'},
#      'cited_phase': 'APP'},
#     {'sequence': 13,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2012119113',
#        'kind': 'A1',
#        'date': '2012-05-17'},
#       'lens_id': '174-884-430-305-020'},
#      'cited_phase': 'APP'},
#     {'sequence': 14,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2012142174',
#        'kind': 'A1',
#        'date': '2012-06-07'},
#       'lens_id': '044-694-031-269-228'},
#      'cited_phase': 'APP'},
#     {'sequence': 15,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2013137250',
#        'kind': 'A1',
#        'date': '2013-05-30'},
#       'lens_id': '024-616-574-262-98X'},
#      'cited_phase': 'APP'},
#     {'sequence': 16,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2013260543',
#        'kind': 'A1',
#        'date': '2013-10-03'},
#       'lens_id': '024-791-158-756-954'},
#      'cited_phase': 'APP'},
#     {'sequence': 17,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2013260544',
#        'kind': 'A1',
#        'date': '2013-10-03'},
#       'lens_id': '144-676-703-728-367'},
#      'cited_phase': 'APP'},
#     {'sequence': 18,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2015024579',
#        'kind': 'A1',
#        'date': '2015-01-22'},
#       'lens_id': '150-581-259-501-62X'},
#      'cited_phase': 'APP'},
#     {'sequence': 19,
#      'patcit': {'document_id': {'jurisdiction': 'US',
#        'doc_number': '2019027341',
#        'kind': 'A1',
#        'date': '2019-01-24'},
#       'lens_id': '179-502-731-853-501'},
#      'cited_phase': 'APP'},
#     {'sequence': 20,
#      'patcit': {'document_id': {'jurisdiction': 'CN',
#        'doc_number': '101681782',
#        'kind': 'A',
#        'date': '2010-03-24'},
#       'lens_id': '107-708-080-455-383'},
#      'cited_phase': 'APP'},
#     {'sequence': 21,
#      'patcit': {'document_id': {'jurisdiction': 'CN',
#        'doc_number': '101946308',
#        'kind': 'A',
#        'date': '2011-01-12'},
#       'lens_id': '068-278-114-875-563'},
#      'cited_phase': 'APP'},
#     {'sequence': 22,
#      'patcit': {'document_id': {'jurisdiction': 'JP',
#        'doc_number': '2009506580',
#        'kind': 'A',
#        'date': '2009-02-12'},
#       'lens_id': '189-565-460-736-91X'},
#      'cited_phase': 'APP'},
#     {'sequence': 23,
#      'patcit': {'document_id': {'jurisdiction': 'JP',
#        'doc_number': '2009539256',
#        'kind': 'A',
#        'date': '2009-11-12'},
#       'lens_id': '142-642-662-065-203'},
#      'cited_phase': 'APP'},
#     {'sequence': 24,
#      'patcit': {'document_id': {'jurisdiction': 'JP',
#        'doc_number': '2010512649',
#        'kind': 'A',
#        'date': '2010-04-22'},
#       'lens_id': '050-392-116-709-724'},
#      'cited_phase': 'APP'},
#     {'sequence': 25,
#      'patcit': {'document_id': {'jurisdiction': 'JP',
#        'doc_number': '2010517304',
#        'kind': 'A',
#        'date': '2010-05-20'},
#       'lens_id': '080-111-423-492-531'},
#      'cited_phase': 'APP'},
#     {'sequence': 26,
#      'patcit': {'document_id': {'jurisdiction': 'JP',
#        'doc_number': '2010522966',
#        'kind': 'A',
#        'date': '2010-07-08'},
#       'lens_id': '000-030-230-727-019'},
#      'cited_phase': 'APP'},
#     {'sequence': 27,
#      'patcit': {'document_id': {'jurisdiction': 'JP',
#        'doc_number': '2012511104',
#        'kind': 'A',
#        'date': '2012-05-17'},
#       'lens_id': '130-516-286-719-628'},
#      'cited_phase': 'APP'},
#     {'sequence': 28,
#      'patcit': {'document_id': {'jurisdiction': 'KR',
#        'doc_number': '20090113855',
#        'kind': 'A',
#        'date': '2009-11-02'},
#       'lens_id': '060-831-299-297-404'},
#      'cited_phase': 'APP'},
#     {'sequence': 29,
#      'patcit': {'document_id': {'jurisdiction': 'KR',
#        'doc_number': '20100015890',
#        'kind': 'A',
#        'date': '2010-02-12'},
#       'lens_id': '011-627-722-961-11X'},
#      'cited_phase': 'APP'},
#     {'sequence': 30,
#      'patcit': {'document_id': {'jurisdiction': 'KR',
#        'doc_number': '20120034798',
#        'kind': 'A',
#        'date': '2012-04-12'},
#       'lens_id': '020-337-928-110-637'},
#      'cited_phase': 'APP'},
#     {'sequence': 31,
#      'patcit': {'document_id': {'jurisdiction': 'KR',
#        'doc_number': '20130138813',
#        'kind': 'A',
#        'date': '2013-12-19'},
#       'lens_id': '008-051-535-741-245'},
#      'cited_phase': 'APP'},
#     {'sequence': 32,
#      'patcit': {'document_id': {'jurisdiction': 'TW',
#        'doc_number': '200836229',
#        'kind': 'A',
#        'date': '2008-09-01'},
#       'lens_id': '161-568-752-248-94X'},
#      'cited_phase': 'APP'},
#     {'sequence': 33,
#      'patcit': {'document_id': {'jurisdiction': 'TW',
#        'doc_number': '200849309',
#        'kind': 'A',
#        'date': '2008-12-16'},
#       'lens_id': '024-202-204-583-17X'},
#      'cited_phase': 'APP'},
#     {'sequence': 34,
#      'patcit': {'document_id': {'jurisdiction': 'TW',
#        'doc_number': '201142908',
#        'kind': 'A',
#        'date': '2011-12-01'},
#       'lens_id': '046-844-457-119-423'},
#      'cited_phase': 'APP'},
#     {'sequence': 35,
#      'patcit': {'document_id': {'jurisdiction': 'TW',
#        'doc_number': '201312634',
#        'kind': 'A',
#        'date': '2013-03-16'},
#       'lens_id': '090-128-264-394-777'},
#      'cited_phase': 'APP'},
#     {'sequence': 36,
#      'patcit': {'document_id': {'jurisdiction': 'TW',
#        'doc_number': '201344765',
#        'kind': 'A',
#        'date': '2013-11-01'},
#       'lens_id': '197-377-770-614-477'},
#      'cited_phase': 'APP'},
#     {'sequence': 37,
#      'nplcit': {'text': 'International Search Report and Written Opinion dated Nov. 28, 2014 in corresponding PCT application No. PCT/US2014/047103.'},
#      'cited_phase': 'APP'},
#     {'sequence': 38,
#      'nplcit': {'text': 'Office action dated Apr. 17, 2019 in co-pending U.S. Appl. No. 16/137,803.'},
#      'cited_phase': 'APP'},
#     {'sequence': 39,
#      'nplcit': {'text': 'Office action dated Sep. 4, 2019 in co-pending U.S. Appl. No. 16/137,803.'},
#      'cited_phase': 'APP'},
#     {'sequence': 40,
#      'nplcit': {'text': 'Final rejection dated Mar. 4, 2020 in co-pending U.S. Appl. No. 16/137,803.'},
#      'cited_phase': 'APP'}],
#    'npl_count': 4,
#    'patent_count': 42},
#   'cited_by': {}},
#  'families': {'simple_family': {'members': [{'document_id': {'jurisdiction': 'CN',
#       'doc_number': '105378896',
#       'kind': 'A',
#       'date': '2016-03-02'},
#      'lens_id': '166-823-120-947-491'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201511071',
#       'kind': 'A',
#       'date': '2015-03-16'},
#      'lens_id': '186-072-492-775-556'},
#     {'document_id': {'jurisdiction': 'CN',
#       'doc_number': '105378896',
#       'kind': 'B',
#       'date': '2018-06-15'},
#      'lens_id': '125-212-421-026-952'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20150024579',
#       'kind': 'A1',
#       'date': '2015-01-22'},
#      'lens_id': '150-581-259-501-62X'},
#     {'document_id': {'jurisdiction': 'KR',
#       'doc_number': '101820421',
#       'kind': 'B1',
#       'date': '2018-01-19'},
#      'lens_id': '079-469-247-118-372'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '10825653',
#       'kind': 'B2',
#       'date': '2020-11-03'},
#      'lens_id': '118-094-508-279-970'},
#     {'document_id': {'jurisdiction': 'JP',
#       'doc_number': '6577947',
#       'kind': 'B2',
#       'date': '2019-09-18'},
#      'lens_id': '125-801-752-519-829'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I615881',
#       'kind': 'B',
#       'date': '2018-02-21'},
#      'lens_id': '013-545-817-172-512'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I720361',
#       'kind': 'B',
#       'date': '2021-03-01'},
#      'lens_id': '046-582-209-611-120'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20170062182',
#       'kind': 'A1',
#       'date': '2017-03-02'},
#      'lens_id': '068-374-926-957-804'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '10804075',
#       'kind': 'B2',
#       'date': '2020-10-13'},
#      'lens_id': '002-152-403-917-266'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201807737',
#       'kind': 'A',
#       'date': '2018-03-01'},
#      'lens_id': '180-701-979-506-287'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201903815',
#       'kind': 'A',
#       'date': '2019-01-16'},
#      'lens_id': '010-720-478-796-078'},
#     {'document_id': {'jurisdiction': 'KR',
#       'doc_number': '20160033168',
#       'kind': 'A',
#       'date': '2016-03-25'},
#      'lens_id': '056-341-960-890-82X'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '9524849',
#       'kind': 'B2',
#       'date': '2016-12-20'},
#      'lens_id': '040-039-168-768-531'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20190027341',
#       'kind': 'A1',
#       'date': '2019-01-24'},
#      'lens_id': '179-502-731-853-501'},
#     {'document_id': {'jurisdiction': 'JP',
#       'doc_number': '2016529704',
#       'kind': 'A',
#       'date': '2016-09-23'},
#      'lens_id': '137-032-844-633-364'},
#     {'document_id': {'jurisdiction': 'WO',
#       'doc_number': '2015009975',
#       'kind': 'A1',
#       'date': '2015-01-22'},
#      'lens_id': '142-995-012-175-527'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I644339',
#       'kind': 'B',
#       'date': '2018-12-11'},
#      'lens_id': '096-039-828-723-091'}],
#    'size': 19},
#   'extended_family': {'members': [{'document_id': {'jurisdiction': 'KR',
#       'doc_number': '101820421',
#       'kind': 'B1',
#       'date': '2018-01-19'},
#      'lens_id': '079-469-247-118-372'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '10825653',
#       'kind': 'B2',
#       'date': '2020-11-03'},
#      'lens_id': '118-094-508-279-970'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20150024579',
#       'kind': 'A1',
#       'date': '2015-01-22'},
#      'lens_id': '150-581-259-501-62X'},
#     {'document_id': {'jurisdiction': 'CN',
#       'doc_number': '105378896',
#       'kind': 'B',
#       'date': '2018-06-15'},
#      'lens_id': '125-212-421-026-952'},
#     {'document_id': {'jurisdiction': 'JP',
#       'doc_number': '2017502503',
#       'kind': 'A',
#       'date': '2017-01-19'},
#      'lens_id': '149-030-729-816-671'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '10804075',
#       'kind': 'B2',
#       'date': '2020-10-13'},
#      'lens_id': '002-152-403-917-266'},
#     {'document_id': {'jurisdiction': 'CN',
#       'doc_number': '105849869',
#       'kind': 'B',
#       'date': '2017-08-11'},
#      'lens_id': '141-012-572-700-741'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201903815',
#       'kind': 'A',
#       'date': '2019-01-16'},
#      'lens_id': '010-720-478-796-078'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20190027341',
#       'kind': 'A1',
#       'date': '2019-01-24'},
#      'lens_id': '179-502-731-853-501'},
#     {'document_id': {'jurisdiction': 'JP',
#       'doc_number': '2016529704',
#       'kind': 'A',
#       'date': '2016-09-23'},
#      'lens_id': '137-032-844-633-364'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I644339',
#       'kind': 'B',
#       'date': '2018-12-11'},
#      'lens_id': '096-039-828-723-091'},
#     {'document_id': {'jurisdiction': 'CN',
#       'doc_number': '105378896',
#       'kind': 'A',
#       'date': '2016-03-02'},
#      'lens_id': '166-823-120-947-491'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201511071',
#       'kind': 'A',
#       'date': '2015-03-16'},
#      'lens_id': '186-072-492-775-556'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20170062182',
#       'kind': 'A1',
#       'date': '2017-03-02'},
#      'lens_id': '068-374-926-957-804'},
#     {'document_id': {'jurisdiction': 'JP',
#       'doc_number': '6577947',
#       'kind': 'B2',
#       'date': '2019-09-18'},
#      'lens_id': '125-801-752-519-829'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201526084',
#       'kind': 'A',
#       'date': '2015-07-01'},
#      'lens_id': '028-518-985-390-499'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I615881',
#       'kind': 'B',
#       'date': '2018-02-21'},
#      'lens_id': '013-545-817-172-512'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I720361',
#       'kind': 'B',
#       'date': '2021-03-01'},
#      'lens_id': '046-582-209-611-120'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '20150024580',
#       'kind': 'A1',
#       'date': '2015-01-22'},
#      'lens_id': '043-949-527-214-04X'},
#     {'document_id': {'jurisdiction': 'KR',
#       'doc_number': '20160089490',
#       'kind': 'A',
#       'date': '2016-07-27'},
#      'lens_id': '106-359-653-761-419'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '9034743',
#       'kind': 'B2',
#       'date': '2015-05-19'},
#      'lens_id': '160-707-291-679-632'},
#     {'document_id': {'jurisdiction': 'CN',
#       'doc_number': '105849869',
#       'kind': 'A',
#       'date': '2016-08-10'},
#      'lens_id': '096-066-080-892-728'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': '201807737',
#       'kind': 'A',
#       'date': '2018-03-01'},
#      'lens_id': '180-701-979-506-287'},
#     {'document_id': {'jurisdiction': 'KR',
#       'doc_number': '20160033168',
#       'kind': 'A',
#       'date': '2016-03-25'},
#      'lens_id': '056-341-960-890-82X'},
#     {'document_id': {'jurisdiction': 'US',
#       'doc_number': '9524849',
#       'kind': 'B2',
#       'date': '2016-12-20'},
#      'lens_id': '040-039-168-768-531'},
#     {'document_id': {'jurisdiction': 'WO',
#       'doc_number': '2015009975',
#       'kind': 'A1',
#       'date': '2015-01-22'},
#      'lens_id': '142-995-012-175-527'},
#     {'document_id': {'jurisdiction': 'TW',
#       'doc_number': 'I642091',
#       'kind': 'B',
#       'date': '2018-11-21'},
#      'lens_id': '116-381-628-523-64X'},
#     {'document_id': {'jurisdiction': 'JP',
#       'doc_number': '6412573',
#       'kind': 'B2',
#       'date': '2018-10-24'},
#      'lens_id': '040-626-221-032-088'},
#     {'document_id': {'jurisdiction': 'WO',
#       'doc_number': '2015080843',
#       'kind': 'A1',
#       'date': '2015-06-04'},
#      'lens_id': '112-325-714-858-997'},
#     {'document_id': {'jurisdiction': 'KR',
#       'doc_number': '102272833',
#       'kind': 'B1',
#       'date': '2021-07-06'},
#      'lens_id': '087-300-859-026-459'}],
#    'size': 30}},
#  'legal_status': {'granted': True,
#   'grant_date': '2020-10-13',
#   'anticipated_term_date': '2034-10-16',
#   'has_disclaimer': True,
#   'calculation_log': ['Application Filing Date: 2016-11-14',
#    'Earliest Filing Date: 2013-11-26 priority to US201314089916A',
#    'Granted Date: 2020-10-13',
#    'Applied 324 days term extension.',
#    'This patent is subject to a terminal disclaimer.',
#    'Anticipated Termination Date: 2034-10-16'],
#   'patent_status': 'ACTIVE'},
#  'abstract': [{'text': 'A method for improving the ion beam quality in an ion implanter is disclosed. In some ion implantation systems, contaminants from the ion source are extracted with the desired ions, introducing contaminants to the workpiece. These contaminants may be impurities in the ion source chamber. This problem is exacerbated when mass analysis of the extracted ion beam is not performed, and is further exaggerated when the desired feedgas includes a halogen. The introduction of a diluent gas in the ion chamber may reduce the deleterious effects of the halogen on the inner surfaces of the chamber, reducing contaminants in the extracted ion beam. In some embodiments, the diluent gas may be germane or silane.',
#    'lang': 'en'}],
#  'claims': [{'claims': [{'claim_text': ['1. A method of implanting ions into a workpiece, comprising: introducing a first source gas and a second source gas into a chamber of an ion source, wherein chamber walls of said ion source are graphite, said first source gas comprising molecules containing a dopant and fluorine, and said second source gas comprising molecules containing hydrogen and germanium, wherein said dopant is different from germanium; ionizing said first source gas and said second source gas in said chamber, wherein germanium from said second source gas coats the chamber walls; extracting ions of said first source gas and said second source gas from said chamber and accelerating said ions toward said workpiece; and implanting the ions in said workpiece without mass analysis.']},
#     {'claim_text': ['2. The method of claim 1 , wherein said dopant comprises a Group 3 element.']},
#     {'claim_text': ['3. The method of claim 1 , wherein said dopant comprises a Group 5 element.']},
#     {'claim_text': ['4. The method of claim 1 , where between 10% and 20% of a total volume of gas introduced comprises the second source gas and a remainder of the total volume of gas introduced is the first source gas.']}],
#    'lang': 'en'}],
#  'description': {'text': 'This application is a continuation of U.S. patent application Ser. No. 14/089,916 filed Nov. 26, 2013, which claims priority of U.S. Provisional Patent Application Ser. No. 61/847,776, filed Jul. 18, 2013, the disclosures of which are incorporated by reference. FIELD Embodiments of the present disclosure relate to methods for improving ion beam quality in an ion implantation system, and more particularly, improving boron ion beam quality. BACKGROUND Semiconductor workpieces are often implanted with dopant species to create a desired conductivity. For example, solar cells may be implanted with a dopant species to create an emitter region. This implant may be done using a variety of different mechanisms. In one embodiment, an ion source is used. This ion source may include a chamber in which source gasses are ionized. The ions from these source gasses may be extracted through an aperture in the chamber, using one or more electrodes. These extracted ions are directed toward a workpiece, where they are implanted in the workpiece to form the solar cell. In an effort to improve process efficiency and lower cost, in some embodiments, the ions extracted from the ion source are accelerated directly toward the workpiece, without any mass analysis. In other words, the ions that are generated in the ion source are accelerated and implanted directly into the workpiece. A mass analyzer is used to remove undesired species from the ion beam. Removal of the mass analyzer implies that all ions extracted from the ion source will be implanted in the workpiece. Consequently, undesired ions, which may also be generated within the ion source, are then implanted in the workpiece. This phenomenon may be most pronounced when the source gas is a halogen-based compound, such as a fluoride. Fluorine ions and neutrals (metastable or excited) may react with the inner surfaces of the ion source, releasing unwanted ions, such as silicon, oxygen, carbon, and aluminum and heavy metals present as impurity elements. Therefore, a method which improves beam quality, particular for embodiments in which halogen based source gasses are employed, would be beneficial. SUMMARY A method for improving the ion beam quality in an ion implanter is disclosed. In some ion implantation systems, contaminants from the ion source are extracted with the desired ions, introducing contaminants to the workpiece. These contaminants may be impurities in the ion source chamber. This problem is exacerbated when mass analysis of the extracted ion beam is not performed, and is further exaggerated when the desired feedgas includes a halogen. The introduction of a diluent gas in the ion chamber may reduce the deleterious effects of the halogen on the inner surfaces of the chamber, reducing contaminants in the extracted ion beam. In some embodiments, the diluent gas may be germane or silane. In one embodiment, a method of implanting dopant into a workpiece is disclosed. The method comprises introducing a feedgas and a diluent gas into a chamber of an ion source, the feedgas comprising molecules comprising a dopant and fluoride, wherein the dopant comprises a Group 3 or Group 5 element, and the diluent gas comprises molecules comprising hydrogen and a Group 4 element or molecules comprising hydrogen and a species having an opposite conductivity as the dopant, where between 3% and 40% of a total volume of gas introduced comprises the diluent gas and a remainder of the total volume comprises the feedgas; ionizing the feedgas and the diluent gas in the chamber; and extracting ions from the chamber and accelerating the ions toward the workpiece. In another embodiment, a method of implanting boron into a workpiece is disclosed. The method comprises introducing a feedgas and a diluent gas into a chamber of an ion source, the feedgas comprising molecules containing boron and fluorine, the diluent gas comprising molecules containing hydrogen and a Group V, where between 3% and  ...
#   'lang': 'en'},
#  'publication_type': 'GRANTED_PATENT'}
